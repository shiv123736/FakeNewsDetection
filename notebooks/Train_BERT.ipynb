# %% [markdown]
# # Fake News Detection: Train DistilBERT
# Steps:
# 1. Install requirements
# 2. Upload `Fake.csv` and `True.csv` to `/content/FakeNewsDetection/data/`
# 3. Preprocess & Split
# 4. Train & Evaluate

# %%
# !pip -q install -r /content/FakeNewsDetection/requirements.txt
import os
os.makedirs('/content/FakeNewsDetection', exist_ok=True)

# %%
# %%bash
# python /content/FakeNewsDetection/src/preprocessing.py \
#   --fake_path /content/FakeNewsDetection/data/Fake.csv \
#   --real_path /content/FakeNewsDetection/data/True.csv \
#   --out_dir /content/FakeNewsDetection/data

# %%
# %%bash
# python /content/FakeNewsDetection/src/train_model.py \
#   --train_path /content/FakeNewsDetection/data/train.csv \
#   --val_path /content/FakeNewsDetection/data/val.csv \
#   --model_name distilbert-base-uncased \
#   --out_dir /content/FakeNewsDetection/model
